# %% [markdown]
# # Data Check

# %%
# -*- coding: utf-8 -*-
execfile("includes.py")
# %matplotlib inline

init() #configure the size of figures

# %%
df=sqlDataFrame("SELECT * FROM gpmc_156_102017")

#converte a coluna data para datetime
df['data']=pd.to_datetime(df['data'])
print (df.shape)
df.dtypes
# Out:
# (73549, 24)
# solicitacao                  int64
# tipo                        object
# orgao                       object
# data                datetime64[ns]
# horario                     object
# assunto                     object
# subdivisao                  object
# descricao                   object
# logradouro_ass              object
# bairro_ass                  object
# regional_ass                object
# meio_resposta               object
# observacao                  object
# sexo                        object
# bairro_cidadao              object
# regional_cidadao            object
# data_nasc                   object
# tipo_cidadao                object
# orgao_resp                  object
# resposta_final              object
# extra                       object
# extra2                      object
# lat                        float64
# lon                        float64
# dtype: object

# %%
df.head()
# Out:
#    solicitacao         tipo orgao       data   horario                                         assunto                                    subdivisao                                          descricao                             logradouro_ass   bairro_ass                  regional_ass meio_resposta                                         observacao sexo bairro_cidadao              regional_cidadao                  data_nasc tipo_cidadao                              orgao_resp  \
# 0      7080042   RECLAMAÇÃO  None 2017-10-24  19:02:11                                  POSTO DE SAÚDE   RECURSOS HUMANOS - ATENDIMENTO PROFISSIONAL  RECLAMA DO ATENDIMENTO DA FUNCIONÁRIA QUE TRAB...  PROFESSOR JÚLIO THEODORICO GUIMARÃES, 337  PINHEIRINHO  Unidade Regional Pinheirinho         EMAIL                                               None    F    PINHEIRINHO  Unidade Regional Pinheirinho  14/11/1988                     CIDADÃO           SECRETARIA MUNICIPAL DA SAÚDE
# ...

# %%
df.describe()
# Out:
#         solicitacao          lat          lon
# count  7.354900e+04  6653.000000  6653.000000
# mean   7.032461e+06   -25.440799   -49.272538
# std    2.701241e+04     0.020998     0.016470
# min    6.987501e+06   -25.563188   -49.351959
# 25%    7.009272e+06   -25.446745   -49.284367
# 50%    7.031406e+06   -25.436710   -49.271814
# 75%    7.054525e+06   -25.429470   -49.261456
# max    7.088495e+06   -25.339798   -49.191508
